# %%
#!/usr/bin/env python
# coding: utf-8

# Import libraries
import json
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset
import pandas as pd
import numpy as np
from typing import Dict
from pathlib import Path
from sklearn.metrics import confusion_matrix
from sklearn import metrics
import matplotlib.pyplot as plt
import os
import time
from scipy.io import savemat
import dill as pickle
import thop
from scipy import stats

# GPU configuration
os.environ["CUDA_VISIBLE_DEVICES"] = "0"  # Select the GPU index

# Define all important parameters at the beginning
device = 'cuda' if torch.cuda.is_available() else 'cpu'
batch_size = 3000
lr = 1e-3
min_lr = 1e-6  # Define your desired minimum learning rate
num_epochs = 2000
patience = 500
num_runs = 50  # Number of runs for statistical confidence
weight_decay = 1e-4
hidden_size = 4196
input_grid_size = 10  # 10m grid size
train_size_ratio = 0.8
val_size_ratio = 0.20
folder_path = "Datasets/"
file_name = f"all_measurements_{input_grid_size}m_25k.json"
file_name_grid = f"all_measurements_grid_{input_grid_size}m.json"

# Create path directory for saving model weights and results
path_directory = f"finalmodels/CNN/Grid_{input_grid_size}m/batch_size_{batch_size}/initial_lr_{lr}/epochs{num_epochs}_p{patience}_hs{hidden_size}/"

# Create directory if it doesn't exist
if not os.path.exists(path_directory):
    os.makedirs(path_directory)

def load_json_file(folder_path, file_name):
    file_path = Path(folder_path) / file_name
    try:
        with open(file_path, 'r') as file:
            return json.load(file)
    except FileNotFoundError:
        print(f"Error: File '{file_name}' not found in '{folder_path}'")
        return None
    except json.JSONDecodeError:
        print(f"Error: Unable to parse JSON from file '{file_name}'")
        return None

def normalize_serving_cell_measurements(df):
    params = ['RSRP', 'RSRQ', 'RSSI', 'SINR']
    norm_params = {}
    
    for metric in params:
        col_name = f"Serving_{metric}"
        if col_name in df.columns:
            mean_val = df[col_name].mean()
            std_val = df[col_name].std()
            
            norm_params[f"{col_name}_mean"] = mean_val
            norm_params[f"{col_name}_std"] = std_val
            
            if std_val != 0:
                df[col_name] = (df[col_name] - mean_val) / std_val
            else:
                print(f"Warning: Standard deviation is 0 for {col_name}")
                df[col_name] = df[col_name] - mean_val
    
    return df, norm_params

def normalize_neighbor_cell_measurements(df, max_neighbors):
    params = ['RSRP', 'RSRQ', 'RSSI']
    norm_params = {}
    
    for i in range(1, max_neighbors + 1):
        for metric in params:
            col_name = f"Neighbor_{i}_{metric}"
            if col_name in df.columns:
                mean_val = df[col_name].mean()
                std_val = df[col_name].std()
                
                norm_params[f"{col_name}_mean"] = mean_val
                norm_params[f"{col_name}_std"] = std_val
                
                if std_val != 0:
                    df[col_name] = (df[col_name] - mean_val) / std_val
                else:
                    print(f"Warning: Standard deviation is 0 for {col_name}")
                    df[col_name] = df[col_name] - mean_val
    
    return df, norm_params

def normalize_position_minmax(df):
    x_min = df['X_Position'].min()
    x_max = df['X_Position'].max()
    y_min = df['Y_Position'].min()
    y_max = df['Y_Position'].max()
    
    position_params = {
        'x_min': x_min,
        'x_max': x_max,
        'y_min': y_min,
        'y_max': y_max
    }
    
    df['X_Position'] = (df['X_Position'] - x_min) / (x_max - x_min)
    df['Y_Position'] = (df['Y_Position'] - y_min) / (y_max - y_min)
    
    return df, position_params

def preprocess_data(json_data):
    ue_data = []
    max_neighbors = 0
    for ue in json_data['UEs']:
        ue_info = {
            'UE_ID': ue['id'],
            'X_Position': ue['position']['x'],
            'Y_Position': ue['position']['y'],
            'Serving_PCI': ue['servingCell']['pci'],
            'Serving_RSRP': ue['servingCell']['rsrp'],
            'Serving_RSRQ': ue['servingCell']['rsrq'],
            'Serving_RSSI': ue['servingCell']['rssi'],
            'Serving_SINR': ue['servingCell']['sinr'],
            'Closest_Grid_dist': ue['gridDetail']['gridCenterDistance'],
            'Closest_Grid_X': ue['gridDetail']['gridCenterX'],
            'Closest_Grid_Y': ue['gridDetail']['gridCenterY'],
            'Closest_Grid_ID': ue['gridDetail']['gridId']
        }
        
        if 'neighborCells' in ue and isinstance(ue['neighborCells'], list):
            for i, neighbor in enumerate(ue['neighborCells']):
                ue_info[f'Neighbor_{i+1}_RSRP'] = neighbor.get('rsrp', 0)
                ue_info[f'Neighbor_{i+1}_RSRQ'] = neighbor.get('rsrq', 0)
                ue_info[f'Neighbor_{i+1}_RSSI'] = neighbor.get('rssi', 0)
            max_neighbors = max(max_neighbors, len(ue['neighborCells']))
        
        ue_data.append(ue_info)
    
    df = pd.DataFrame(ue_data)
    
    for i in range(1, max_neighbors + 1):
        for metric in ['RSRP', 'RSRQ', 'RSSI']:
            col_name = f'Neighbor_{i}_{metric}'
            if col_name not in df.columns:
                df[col_name] = 0
            else:
                df[col_name] = df[col_name].fillna(0)
    
    df, position_params = normalize_position_minmax(df)
    df.attrs.update(position_params)
    
    df, serving_params = normalize_serving_cell_measurements(df)
    df.attrs.update(serving_params)
    
    df, neighbor_params = normalize_neighbor_cell_measurements(df, max_neighbors)
    df.attrs.update(neighbor_params)
    
    features = np.array(df.drop(['UE_ID', 'X_Position', 'Y_Position', 'Serving_PCI', 'Closest_Grid_dist', 
                                'Closest_Grid_X', 'Closest_Grid_Y', 'Closest_Grid_ID'], axis=1))
    
    labels = np.array(df[['X_Position', 'Y_Position']])
    grid_id = np.array(df['Closest_Grid_ID'])
    
    indices = np.arange(len(features))
    np.random.shuffle(indices)
    features = features[indices]
    labels = labels[indices]
    grid_id = grid_id[indices]
    
    # Reshape features for CNN input (batch_size, channels, height, width)
    features = features.reshape(-1, 1, features.shape[1], 1)
    features = torch.tensor(features, dtype=torch.float32)
    labels = torch.tensor(labels, dtype=torch.float32)
    grid_id = torch.tensor(grid_id, dtype=torch.float32)
    
    return features, labels, grid_id, df

class GridDataPreprocessor:
    def __init__(self, json_path, json_file: str):
        """
        Initialize the preprocessor with path to JSON file
        """
        self.json_path = Path(json_path)/json_file
        self.raw_data = self._load_json()
        
    def _load_json(self) -> Dict:
        """Load JSON file and return the data"""
        with open(self.json_path, 'r') as f:
            return json.load(f)
    
    def _extract_grid_coordinates(self, grid_dict: Dict) -> torch.Tensor:
        """
        Extract coordinates from a single grid dictionary
        """
        points = []
        for point in grid_dict['gridDictionary']:
            points.append([
                point['gridCenterX'],
                point['gridCenterY'],
                point['gridId']
            ])
        return torch.tensor(points, dtype=torch.float32)
    
    def process_data(self) -> Dict[str, torch.Tensor]:
        """
        Process all grids in the data
        """
        all_grids = []
        
        for grid in self.raw_data['GRIDs']:
            grid_tensor = self._extract_grid_coordinates(grid)
            all_grids.append(grid_tensor)
            
        # Stack all grids into a single tensor
        all_grids_tensor = torch.stack(all_grids)
        
        # Split into coordinates and grid IDs
        grid_centers = all_grids_tensor[..., :2]  # Shape: (num_grids, num_points, 2)
        grid_ids = all_grids_tensor[..., 2]      # Shape: (num_grids, num_points)
        
        return {
            'coordinates': all_grids_tensor,      # Full data
            'grid_centers': grid_centers,         # Just x,y coordinates
            'grid_ids': grid_ids                  # Just grid IDs
        }

def gaussian_grid_probability(predicted_coords, grid_centers, sigma=50):
    # Calculate distances
    distances = np.sqrt(((grid_centers - predicted_coords[:, np.newaxis]) ** 2).sum(axis=2))
    # Apply Gaussian kernel
    probabilities = np.exp(-distances**2 / (2 * sigma**2))
    return probabilities / probabilities.sum(axis=1, keepdims=True)

def softmax_grid_probability(predicted_coords, grid_centers, temperature=1.0):
    # Calculate distances
    distances = np.sqrt(((grid_centers - predicted_coords[:, np.newaxis]) ** 2).sum(axis=2))
    # Apply softmax with temperature scaling
    logits = -distances / temperature
    exp_logits = np.exp(logits - np.max(logits, axis=1, keepdims=True))
    return exp_logits / exp_logits.sum(axis=1, keepdims=True)

def calculate_confidence_interval(data, confidence=0.95):
    n = len(data)
    mean = np.mean(data)
    se = stats.sem(data)
    h = se * stats.t.ppf((1 + confidence) / 2., n-1)
    return mean, h

class CNNPositioningModel(nn.Module):
    def __init__(self, input_channels, hidden_size=1024):
        super(CNNPositioningModel, self).__init__()
        
        # CNN layers
        self.conv_layers = nn.Sequential(
            nn.Conv2d(1, hidden_size // 32, kernel_size=(input_channels, 1), padding=(1, 0)),
            nn.BatchNorm2d(hidden_size // 32),
            nn.ReLU(),
            nn.Conv2d(hidden_size // 32, hidden_size // 16, kernel_size=(3, 1), padding=(1, 0)),
            nn.BatchNorm2d(hidden_size // 16),
            nn.ReLU(),
            nn.Conv2d(hidden_size // 16, hidden_size // 8, kernel_size=(3, 1), padding=(1, 0)),
            nn.BatchNorm2d(hidden_size // 8),
            nn.ReLU(),
            nn.Conv2d(hidden_size // 8, hidden_size // 4, kernel_size=(3, 1), padding=(1, 0)),
            nn.BatchNorm2d(hidden_size // 4),
            nn.ReLU(),
            nn.Conv2d(hidden_size // 4, hidden_size // 2, kernel_size=(3, 1), padding=(1, 0)),
            nn.BatchNorm2d(hidden_size // 2),
            nn.ReLU(), 
            nn.Conv2d(hidden_size // 2, hidden_size, kernel_size=(3, 1), padding=(1, 0)),
            nn.BatchNorm2d(hidden_size),
            nn.ReLU(), 
        )
        
        # Adaptive pooling to handle variable input sizes
        self.adaptive_pool = nn.AdaptiveAvgPool2d((1, 1))
        
        # Fully connected layers
        self.fc_layers = nn.Sequential(
            nn.Flatten(),
            nn.Linear(hidden_size, hidden_size),
            nn.BatchNorm1d(hidden_size),
            nn.ReLU(),
            nn.Dropout(0.1),
            
            nn.Linear(hidden_size, hidden_size // 2),
            nn.BatchNorm1d(hidden_size // 2),
            nn.ReLU(),
            nn.Dropout(0.1),
            
            nn.Linear(hidden_size // 2, hidden_size // 4),
            nn.BatchNorm1d(hidden_size // 4),
            nn.ReLU(),
            nn.Dropout(0.1),
            
            nn.Linear(hidden_size // 4, 2),
            nn.Sigmoid()
        )
        
        # Place model on specified device
        self.to(device)
        
    def forward(self, x):
        x = self.conv_layers(x)
        x = self.adaptive_pool(x)
        x = self.fc_layers(x)
        return x

class CustomDataset(Dataset):
    def __init__(self, features, labels):
        self.features = features
        self.labels = labels
        
    def __len__(self):
        return len(self.features)
    
    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]

def train_model(model, train_loader, val_loader, num_epochs=1000, patience=500, learning_rate=1e-4, path_directory=None):
    criterion = nn.MSELoss().to(device)
    optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
    
    
    # Calculate required final_div_factor based on the desired min_lr
    final_div_factor = learning_rate / min_lr
    scheduler = torch.optim.lr_scheduler.OneCycleLR(
        optimizer,
        max_lr=learning_rate,
        epochs=num_epochs,
        steps_per_epoch=len(train_loader),
        pct_start=0.1,
        anneal_strategy='cos',
        div_factor=25,  # Controls initial learning rate (max_lr/div_factor)
        final_div_factor=final_div_factor  # Controls final learning rate (max_lr/final_div_factor)
    )
    
    best_val_loss = float('inf')
    patience_counter = 0
    train_losses = []
    val_losses = []
    
    for epoch in range(num_epochs):
        epoch_start_time = time.time()
        model.train()
        train_loss = 0.0
        
        for batch_features, batch_labels in train_loader:
            # Move batch to device
            batch_features = batch_features.to(device)
            batch_labels = batch_labels.to(device)
            
            optimizer.zero_grad()
            outputs = model(batch_features)
            loss = criterion(outputs, batch_labels)
            loss.backward()
            
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            
            optimizer.step()
            scheduler.step()
            train_loss += loss.item()
        
        avg_train_loss = train_loss / len(train_loader)
        train_losses.append(avg_train_loss)
        
        model.eval()
        val_loss = 0.0
        with torch.no_grad():
            for batch_features, batch_labels in val_loader:
                # Move batch to device
                batch_features = batch_features.to(device)
                batch_labels = batch_labels.to(device)
                
                outputs = model(batch_features)
                loss = criterion(outputs, batch_labels)
                val_loss += loss.item()
        
        avg_val_loss = val_loss / len(val_loader)
        val_losses.append(avg_val_loss)
        
        epoch_time = time.time() - epoch_start_time
        current_lr = optimizer.param_groups[0]['lr']
        
        if epoch % 10 == 0:
            print(f'epoch:{epoch+1}/{num_epochs} average TL:{avg_train_loss:.8f} average VL:{avg_val_loss:.8f} epoch time:{int(epoch_time)} seconds, lr:{current_lr:.2e}')
        
        if avg_val_loss < best_val_loss:
            best_val_loss = avg_val_loss
            # Save model to the specified path directory
            if path_directory:
                model_path = path_directory + 'best_cnn_model.pth'
                torch.save(model.state_dict(), model_path)
            else:
                torch.save(model.state_dict(), 'best_cnn_model.pth')
            patience_counter = 0
        else:
            patience_counter += 1
            
        if patience_counter >= patience:
            print(f'Early stopping at epoch {epoch+1}')
            break
    
    return train_losses, val_losses

if __name__ == "__main__":
    print(f"Using device: {device}")
    print(f"Model will be saved to: {path_directory}")

    # Load data
    json_data = load_json_file(folder_path, file_name)
    if json_data is None:
        print("Error loading data")
        exit()
    
    # Process grid information
    preprocessor_grid = GridDataPreprocessor(folder_path, file_name_grid)
    processed_data_grid = preprocessor_grid.process_data()
    
    coordinates = processed_data_grid['coordinates'].to(device)
    grid_centers = processed_data_grid['grid_centers'].to(device)
    grid_ids = processed_data_grid['grid_ids'].to(device)
    center = grid_centers.cpu().numpy()[0]
    ids = grid_ids.cpu().numpy()[0]

    # Initial preprocessing for model training
    features, labels, grid_number, df = preprocess_data(json_data)
    
    # Get position normalization parameters for future use
    x_pos_min = df.attrs['x_min']
    x_pos_max = df.attrs['x_max']
    y_pos_min = df.attrs['y_min']
    y_pos_max = df.attrs['y_max']
    
    # Move tensors to device
    features = features.to(device)
    labels = labels.to(device)
    grid_number = grid_number.to(device)
    
    # Calculate split sizes
    total_samples = len(features)
    train_size = int(train_size_ratio * total_samples)
    
    # Split the data for training and validation/testing
    train_features = features[:train_size]
    train_labels = labels[:train_size]
    val_features = features[train_size:]
    val_labels = labels[train_size:]
    test_features = val_features  # Using validation set as test set
    test_labels = val_labels
    test_grid_ids = grid_number[train_size:]

    # Create datasets and dataloaders
    train_dataset = CustomDataset(train_features, train_labels)
    val_dataset = CustomDataset(val_features, val_labels)

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size)

    # Initialize and train the model
    input_channels = features.shape[2]  # Number of features
    model = CNNPositioningModel(input_channels, hidden_size)
    
    # Measure training time
    start_time = time.time()
    train_losses, val_losses = train_model(
        model,
        train_loader,
        val_loader,
        num_epochs=num_epochs,
        patience=patience,
        learning_rate=lr,
        path_directory=path_directory
    )
    training_time = time.time() - start_time
    print(f"Training completed in {training_time:.2f} seconds")
    
    # Calculate model FLOPs and parameters
    dummy_input = torch.randn(1, 1, input_channels, 1).to(device)
    flops, params = thop.profile(model, inputs=(dummy_input,), verbose=False)
    print(f'Model FLOPs: {flops}')
    print(f'Model Params Num: {params}\n')
    
    # Save losses, flops, and parameters in dictionary
    losses_dict = {
        'train_losses': np.array(train_losses), 
        'val_losses': np.array(val_losses), 
        'flops': flops, 
        'parameters': params
    }
    
    # Save in both .mat and .pkl formats
    savemat(path_directory + 'losses.mat', losses_dict)
    with open(path_directory + 'losses.pkl', 'wb') as file:
        pickle.dump(losses_dict, file)
    
    # Save training curves as PDF
    plt.figure(figsize=(10, 6))
    plt.plot(train_losses, label='Train Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.yscale('log')
    plt.title('Training and Validation Loss')
    plt.legend()
    plt.grid(True)
    plt.savefig(path_directory + 'training_curves.pdf')
    
    # Load the best model for evaluation
    model = CNNPositioningModel(input_channels, hidden_size)
    model.load_state_dict(torch.load(path_directory + 'best_cnn_model.pth'))
    model.to(device)
    model.eval()
    
    # --- Initial single evaluation ---
    # Evaluate on test data
    with torch.no_grad():
        outputs_test = model(test_features)
    
    # Convert normalized predictions back to original scale
    predicted = outputs_test.detach().cpu().numpy()
    real = test_labels.cpu().numpy()
    
    # Denormalize predictions
    predicted[:,0] = x_pos_min + predicted[:,0]*(x_pos_max - x_pos_min)
    predicted[:,1] = y_pos_min + predicted[:,1]*(y_pos_max - y_pos_min)
    
    # Denormalize ground truth
    real[:,0] = x_pos_min + real[:,0]*(x_pos_max - x_pos_min)
    real[:,1] = y_pos_min + real[:,1]*(y_pos_max - y_pos_min)
    
    # Calculate distances for grid prediction
    distances = np.sqrt((center[:, np.newaxis, 0] - predicted[:, 0])**2 + 
                        (center[:, np.newaxis, 1] - predicted[:, 1])**2)
    
    # Calculate prediction accuracy using different methods
    # 1. Using reciprocal of distances
    reciprocals = 1 / distances
    column_sums = reciprocals.sum(axis=0)
    probabilities_rec = reciprocals / column_sums
    grid_predicted = np.argmax(probabilities_rec, axis=0)
    grid_real = test_grid_ids.cpu().numpy()
    accuracy = metrics.accuracy_score(grid_real, grid_predicted)
    
    # 2. Using Gaussian kernel
    probabilities_gauss = gaussian_grid_probability(predicted, center, sigma=50)
    grid_predicted_gauss = np.argmax(probabilities_gauss, axis=1)
    accuracy_gauss = metrics.accuracy_score(grid_real, grid_predicted_gauss)
    
    # 3. Using softmax
    probabilities_softmax = softmax_grid_probability(predicted, center, temperature=1.0)
    grid_predicted_softmax = np.argmax(probabilities_softmax, axis=1)
    accuracy_softmax = metrics.accuracy_score(grid_real, grid_predicted_softmax)
    
    # Calculate positioning error
    distance_error = np.linalg.norm(real - predicted, axis=1)
    mean_error = np.mean(distance_error)
    percentile_90 = np.percentile(distance_error, 90)
    
    # Save the confusion matrix for grid prediction
    conf_matrix = confusion_matrix(grid_real, grid_predicted, labels=ids)
    np.save(path_directory + 'confusion_matrix.npy', conf_matrix)
    
    # Print and save single run results
    print(f"\n--- Single Run Results ---")
    print(f"Grid Size: {input_grid_size}m")
    print(f"Mean 2D Error: {mean_error:.2f} meters")
    print(f"90th Percentile Error: {percentile_90:.2f} meters")
    print(f"Grid Accuracy (Reciprocal): {accuracy:.4f}")
    print(f"Grid Accuracy (Gaussian): {accuracy_gauss:.4f}")
    print(f"Grid Accuracy (Softmax): {accuracy_softmax:.4f}")
    print(f"Training Time: {training_time:.2f} seconds")
    
    # Save results to file
    with open(path_directory + 'results_single.txt', 'w') as f:
        f.write(f"Grid Size: {input_grid_size}m\n")
        f.write(f"Mean 2D Error: {mean_error:.2f} meters\n")
        f.write(f"90th Percentile Error: {percentile_90:.2f} meters\n")
        f.write(f"Grid Accuracy (Reciprocal): {accuracy:.4f}\n")
        f.write(f"Grid Accuracy (Gaussian): {accuracy_gauss:.4f}\n")
        f.write(f"Grid Accuracy (Softmax): {accuracy_softmax:.4f}\n")
        f.write(f"Training Time: {training_time:.2f} seconds\n")
    
    # Plot CDF of positioning errors and save as PDF
    plt.figure(figsize=(8, 5))
    sorted_errors = np.sort(distance_error)
    cdf = np.arange(1, len(sorted_errors) + 1) / len(sorted_errors)
    plt.plot(sorted_errors, cdf, label="CDF", color="blue")
    plt.axvline(percentile_90, color="red", linestyle="--", 
                label=f"90th Percentile = {percentile_90:.2f}")
    plt.xlabel("Distance Error (meters)")
    plt.ylabel("Cumulative Probability")
    plt.title(f"CDF of Distance Errors for {input_grid_size}m grid size CNN (Single Run)")
    plt.legend()
    plt.grid()
    plt.savefig(path_directory + 'error_cdf_single.pdf')
    
    # Save performance metrics for single run
    metrics_dict_single = {
        'mean_error': mean_error,
        'percentile_90': percentile_90,
        'accuracy': accuracy,
        'accuracy_gauss': accuracy_gauss,
        'accuracy_softmax': accuracy_softmax,
        'training_time': training_time,
        'sorted_errors': sorted_errors,
        'cdf': cdf
    }
    
    savemat(path_directory + 'metrics_single.mat', metrics_dict_single)
    with open(path_directory + 'metrics_single.pkl', 'wb') as file:
        pickle.dump(metrics_dict_single, file)
    
    # --- Multiple runs for statistical confidence ---
    print(f"\n--- Starting Multiple Run Analysis ({num_runs} runs) ---")
    
    # Lists to store metrics from all runs
    dist_prob_list = []  # Reciprocal distance accuracy
    gauss_prob_list = []  # Gaussian kernel accuracy
    softm_prob_list = []  # Softmax accuracy
    percentile_90_list = []  # 90th percentile errors
    mean_err_list = []  # Mean errors
    all_distance_errors = []  # All distance errors across all runs
    
    # Start multiple runs
    for run in range(num_runs):
        if run % 10 == 0:
            print(f"Run {run+1}/{num_runs}...")
            
        # Preprocess data with different random shuffling
        features_run, labels_run, grid_number_run, _ = preprocess_data(json_data)
        
        # Move tensors to device
        features_run = features_run.to(device)
        labels_run = labels_run.to(device)
        grid_number_run = grid_number_run.to(device)
        
        # Split the data for this run
        train_size = int(train_size_ratio * len(features_run))
        test_features_run = features_run[train_size:]
        test_labels_run = labels_run[train_size:]
        test_grid_ids_run = grid_number_run[train_size:]
        
        # Load the trained model
        model.load_state_dict(torch.load(path_directory + 'best_cnn_model.pth'))
        model.eval()
        
        # Evaluate on test data for this run
        with torch.no_grad():
            outputs_test_run = model(test_features_run)
        
        # Denormalize predictions
        predicted_run = outputs_test_run.detach().cpu().numpy()
        predicted_run[:,0] = x_pos_min + predicted_run[:,0]*(x_pos_max - x_pos_min)
        predicted_run[:,1] = y_pos_min + predicted_run[:,1]*(y_pos_max - y_pos_min)
        
        # Denormalize ground truth
        real_run = test_labels_run.cpu().numpy()
        real_run[:,0] = x_pos_min + real_run[:,0]*(x_pos_max - x_pos_min)
        real_run[:,1] = y_pos_min + real_run[:,1]*(y_pos_max - y_pos_min)
        
        # Calculate distances for grid prediction
        distances_run = np.sqrt((center[:, np.newaxis, 0] - predicted_run[:, 0])**2 + 
                            (center[:, np.newaxis, 1] - predicted_run[:, 1])**2)
        
        # Calculate reciprocal distance accuracy
        reciprocals_run = 1 / distances_run
        column_sums_run = reciprocals_run.sum(axis=0)
        probabilities_rec_run = reciprocals_run / column_sums_run
        grid_predicted_run = np.argmax(probabilities_rec_run, axis=0)
        grid_real_run = test_grid_ids_run.cpu().numpy()
        accuracy_run = metrics.accuracy_score(grid_real_run, grid_predicted_run)
        
        # Calculate Gaussian kernel accuracy
        probabilities_gauss_run = gaussian_grid_probability(predicted_run, center, sigma=50)
        grid_predicted_gauss_run = np.argmax(probabilities_gauss_run, axis=1)
        accuracy_gauss_run = metrics.accuracy_score(grid_real_run, grid_predicted_gauss_run)
        
        # Calculate softmax accuracy
        probabilities_softmax_run = softmax_grid_probability(predicted_run, center, temperature=1.0)
        grid_predicted_softmax_run = np.argmax(probabilities_softmax_run, axis=1)
        accuracy_softmax_run = metrics.accuracy_score(grid_real_run, grid_predicted_softmax_run)
        
        # Calculate positioning error
        distance_error_run = np.linalg.norm(real_run - predicted_run, axis=1)
        mean_error_run = np.mean(distance_error_run)
        percentile_90_run = np.percentile(distance_error_run, 90)
        
        # Store metrics for this run
        dist_prob_list.append(accuracy_run)
        gauss_prob_list.append(accuracy_gauss_run)
        softm_prob_list.append(accuracy_softmax_run)
        percentile_90_list.append(percentile_90_run)
        mean_err_list.append(mean_error_run)
        
        # Store all distance errors for comprehensive CDF
        all_distance_errors.extend(distance_error_run.tolist())
    
    # Calculate mean and confidence intervals for all metrics
    mean_accuracy, margin_of_error_accuracy = calculate_confidence_interval(dist_prob_list)
    mean_accuracy_gauss, margin_of_error_accuracy_gauss = calculate_confidence_interval(gauss_prob_list)
    mean_accuracy_softmax, margin_of_error_accuracy_softmax = calculate_confidence_interval(softm_prob_list)
    mean_percentile_90, margin_of_error_percentile_90 = calculate_confidence_interval(percentile_90_list)
    mean_2D_err, margin_of_error_2D_err = calculate_confidence_interval(mean_err_list)

    # Print results of multiple runs with confidence intervals
    print("\n--- Multiple Run Results with 95% Confidence Intervals ---")
    print(f"Mean 2D Error: {mean_2D_err:.2f} ± {margin_of_error_2D_err:.2f} meters")
    print(f"90th Percentile Error: {mean_percentile_90:.2f} ± {margin_of_error_percentile_90:.2f} meters")
    print(f"Grid Accuracy (Reciprocal): {mean_accuracy:.4f} ± {margin_of_error_accuracy:.4f}")
    print(f"Grid Accuracy (Gaussian): {mean_accuracy_gauss:.4f} ± {margin_of_error_accuracy_gauss:.4f}")
    print(f"Grid Accuracy (Softmax): {mean_accuracy_softmax:.4f} ± {margin_of_error_accuracy_softmax:.4f}")
    
    # Save results to file
    with open(path_directory + 'results_multiple.txt', 'w') as f:
        f.write(f"Grid Size: {input_grid_size}m\n")
        f.write(f"Number of runs: {num_runs}\n\n")
        f.write(f"Mean 2D Error: {mean_2D_err:.2f} ± {margin_of_error_2D_err:.2f} meters\n")
        f.write(f"90th Percentile Error: {mean_percentile_90:.2f} ± {margin_of_error_percentile_90:.2f} meters\n")
        f.write(f"Grid Accuracy (Reciprocal): {mean_accuracy:.4f} ± {margin_of_error_accuracy:.4f}\n")
        f.write(f"Grid Accuracy (Gaussian): {mean_accuracy_gauss:.4f} ± {margin_of_error_accuracy_gauss:.4f}\n")
        f.write(f"Grid Accuracy (Softmax): {mean_accuracy_softmax:.4f} ± {margin_of_error_accuracy_softmax:.4f}\n")
    
    # Plot comprehensive CDF from all runs
    plt.figure(figsize=(8, 5))
    all_sorted_errors = np.sort(all_distance_errors)
    all_cdf = np.arange(1, len(all_sorted_errors) + 1) / len(all_sorted_errors)
    
    # Calculate the 90th percentile from the combined errors
    all_percentile_90 = np.percentile(all_distance_errors, 90)
    
    plt.plot(all_sorted_errors, all_cdf, label="CDF", color="blue")
    plt.axvline(all_percentile_90, color="red", linestyle="--", 
                label=f"90th Percentile = {all_percentile_90:.2f}")
    plt.xlabel("Distance Error (meters)")
    plt.ylabel("Cumulative Probability")
    plt.title(f"CDF of Distance Errors for {input_grid_size}m grid size CNN ({num_runs} runs)")
    plt.legend()
    plt.grid()
    plt.savefig(path_directory + 'error_cdf_multiple.pdf')
    
    # Save comprehensive metrics with confidence intervals
    metrics_dict_multiple = {
        'mean_error': mean_2D_err,
        'mean_error_margin': margin_of_error_2D_err,
        'percentile_90': mean_percentile_90,
        'percentile_90_margin': margin_of_error_percentile_90,
        'accuracy': mean_accuracy,
        'accuracy_margin': margin_of_error_accuracy,
        'accuracy_gauss': mean_accuracy_gauss,
        'accuracy_gauss_margin': margin_of_error_accuracy_gauss,
        'accuracy_softmax': mean_accuracy_softmax,
        'accuracy_softmax_margin': margin_of_error_accuracy_softmax,
        'num_runs': num_runs,
        'all_sorted_errors': all_sorted_errors,
        'all_cdf': all_cdf,
        'all_percentile_90': all_percentile_90,
        'mean_errors_per_run': np.array(mean_err_list),
        'percentile_90_per_run': np.array(percentile_90_list),
        'accuracy_per_run': np.array(dist_prob_list),
        'accuracy_gauss_per_run': np.array(gauss_prob_list),
        'accuracy_softmax_per_run': np.array(softm_prob_list)
    }
    
    savemat(path_directory + 'metrics_multiple.mat', metrics_dict_multiple)
    with open(path_directory + 'metrics_multiple.pkl', 'wb') as file:
        pickle.dump(metrics_dict_multiple, file)
    
    print(f"\nAll results saved to {path_directory}")
    print(f"Training time: {training_time:.2f} seconds")
    print(f"Total evaluation time for {num_runs} runs: {time.time() - start_time - training_time:.2f} seconds")
# Out:
# Using device: cuda
# Model will be saved to: finalmodels/CNN/Grid_10m/batch_size_3000/initial_lr_0.001/epochs2000_p500_hs4196/
# epoch:1/2000 average TL:0.03228805 average VL:0.08389553 epoch time:1 seconds, lr:4.01e-05
# epoch:11/2000 average TL:0.00128442 average VL:0.00060068 epoch time:1 seconds, lr:4.72e-05
# epoch:21/2000 average TL:0.00080838 average VL:0.00062571 epoch time:1 seconds, lr:6.59e-05
# epoch:31/2000 average TL:0.00078252 average VL:0.00062771 epoch time:1 seconds, lr:9.59e-05
# epoch:41/2000 average TL:0.00040964 average VL:0.00017501 epoch time:1 seconds, lr:1.36e-04
# epoch:51/2000 average TL:0.00036579 average VL:0.00023270 epoch time:1 seconds, lr:1.86e-04
# epoch:61/2000 average TL:0.00092800 average VL:0.00066621 epoch time:1 seconds, lr:2.44e-04
# epoch:71/2000 average TL:0.00075786 average VL:0.00090105 epoch time:1 seconds, lr:3.09e-04
# epoch:81/2000 average TL:0.00141517 average VL:0.00068227 epoch time:1 seconds, lr:3.79e-04
# epoch:91/2000 average TL:0.00036519 average VL:0.00013945 epoch time:1 seconds, lr:4.53e-04
# epoch:101/2000 average TL:0.00014655 average VL:0.00005873 epoch time:1 seconds, lr:5.28e-04
# epoch:111/2000 average TL:0.00014121 average VL:0.00004093 epoch time:1 seconds, lr:6.03e-04
# epoch:121/2000 average TL:0.02259004 average VL:0.09683739 epoch time:1 seconds, lr:6.76e-04
# epoch:131/2000 average TL:0.00043674 average VL:0.00025644 epoch time:1 seconds, lr:7.45e-04
# epoch:141/2000 average TL:0.00024881 average VL:0.00010140 epoch time:1 seconds, lr:8.09e-04
# epoch:151/2000 average TL:0.00242636 average VL:0.00203662 epoch time:1 seconds, lr:8.65e-04
# epoch:161/2000 average TL:0.00023444 average VL:0.00009509 epoch time:1 seconds, lr:9.13e-04
# epoch:171/2000 average TL:0.00021373 average VL:0.00014490 epoch time:1 seconds, lr:9.51e-04
# epoch:181/2000 average TL:0.00020099 average VL:0.00008221 epoch time:1 seconds, lr:9.79e-04
# epoch:191/2000 average TL:0.00013930 average VL:0.00004815 epoch time:1 seconds, lr:9.95e-04
# epoch:201/2000 average TL:0.00013821 average VL:0.00008531 epoch time:1 seconds, lr:1.00e-03
# epoch:211/2000 average TL:0.00014782 average VL:0.00005466 epoch time:1 seconds, lr:1.00e-03
# epoch:221/2000 average TL:0.00013199 average VL:0.00005351 epoch time:1 seconds, lr:1.00e-03
# epoch:231/2000 average TL:0.00014528 average VL:0.00005134 epoch time:1 seconds, lr:9.99e-04
# epoch:241/2000 average TL:0.00011799 average VL:0.00003768 epoch time:1 seconds, lr:9.99e-04
# epoch:251/2000 average TL:0.00009647 average VL:0.00003501 epoch time:1 seconds, lr:9.98e-04
# epoch:261/2000 average TL:0.00018573 average VL:0.00010391 epoch time:1 seconds, lr:9.97e-04
# epoch:271/2000 average TL:0.00071055 average VL:0.00054250 epoch time:1 seconds, lr:9.96e-04
# epoch:281/2000 average TL:0.00013242 average VL:0.00006558 epoch time:1 seconds, lr:9.95e-04
# epoch:291/2000 average TL:0.00014753 average VL:0.00009388 epoch time:1 seconds, lr:9.94e-04
# epoch:301/2000 average TL:0.00011658 average VL:0.00002515 epoch time:1 seconds, lr:9.92e-04
# epoch:311/2000 average TL:0.00014425 average VL:0.00004571 epoch time:1 seconds, lr:9.91e-04
# epoch:321/2000 average TL:0.00009378 average VL:0.00002545 epoch time:1 seconds, lr:9.89e-04
# epoch:331/2000 average TL:0.00010961 average VL:0.00004142 epoch time:1 seconds, lr:9.87e-04
# epoch:341/2000 average TL:0.00011085 average VL:0.00003151 epoch time:1 seconds, lr:9.85e-04
# epoch:351/2000 average TL:0.00010511 average VL:0.00001938 epoch time:1 seconds, lr:9.83e-04
# epoch:361/2000 average TL:0.00011815 average VL:0.00004914 epoch time:1 seconds, lr:9.80e-04
# epoch:371/2000 average TL:0.00011613 average VL:0.00004589 epoch time:1 seconds, lr:9.78e-04
# epoch:381/2000 average TL:0.00009915 average VL:0.00005894 epoch time:1 seconds, lr:9.75e-04
# epoch:391/2000 average TL:0.00012965 average VL:0.00013475 epoch time:1 seconds, lr:9.72e-04
# epoch:401/2000 average TL:0.00010010 average VL:0.00006157 epoch time:1 seconds, lr:9.70e-04
# epoch:411/2000 average TL:0.00008130 average VL:0.00002377 epoch time:1 seconds, lr:9.66e-04
# epoch:421/2000 average TL:0.00009598 average VL:0.00004784 epoch time:1 seconds, lr:9.63e-04
# epoch:431/2000 average TL:0.00010563 average VL:0.00005976 epoch time:1 seconds, lr:9.60e-04
# epoch:441/2000 average TL:0.00008832 average VL:0.00004009 epoch time:1 seconds, lr:9.56e-04
# epoch:451/2000 average TL:0.00008030 average VL:0.00003388 epoch time:1 seconds, lr:9.53e-04
# epoch:461/2000 average TL:0.00007759 average VL:0.00004286 epoch time:1 seconds, lr:9.49e-04
# epoch:471/2000 average TL:0.00009359 average VL:0.00004413 epoch time:1 seconds, lr:9.45e-04
# epoch:481/2000 average TL:0.00009697 average VL:0.00005540 epoch time:1 seconds, lr:9.41e-04
# epoch:491/2000 average TL:0.00883057 average VL:0.03085945 epoch time:1 seconds, lr:9.37e-04
# epoch:501/2000 average TL:0.00034159 average VL:0.00032200 epoch time:1 seconds, lr:9.33e-04
# epoch:511/2000 average TL:0.00017374 average VL:0.00015705 epoch time:1 seconds, lr:9.28e-04
# epoch:521/2000 average TL:0.00015686 average VL:0.00007770 epoch time:1 seconds, lr:9.23e-04
# epoch:531/2000 average TL:0.00015464 average VL:0.00015430 epoch time:1 seconds, lr:9.19e-04
# epoch:541/2000 average TL:0.00011467 average VL:0.00006682 epoch time:1 seconds, lr:9.14e-04
# epoch:551/2000 average TL:0.00014480 average VL:0.00007720 epoch time:1 seconds, lr:9.09e-04
# epoch:561/2000 average TL:0.00012667 average VL:0.00005706 epoch time:1 seconds, lr:9.04e-04
# epoch:571/2000 average TL:0.00013241 average VL:0.00006489 epoch time:1 seconds, lr:8.99e-04
# epoch:581/2000 average TL:0.00009658 average VL:0.00006329 epoch time:1 seconds, lr:8.93e-04
# epoch:591/2000 average TL:0.00026518 average VL:0.00050733 epoch time:1 seconds, lr:8.88e-04
# epoch:601/2000 average TL:0.00017356 average VL:0.00009715 epoch time:1 seconds, lr:8.82e-04
# epoch:611/2000 average TL:0.00012345 average VL:0.00007747 epoch time:1 seconds, lr:8.77e-04
# epoch:621/2000 average TL:0.00016317 average VL:0.00021140 epoch time:1 seconds, lr:8.71e-04
# epoch:631/2000 average TL:0.00009316 average VL:0.00003117 epoch time:1 seconds, lr:8.65e-04
# epoch:641/2000 average TL:0.00010554 average VL:0.00003025 epoch time:1 seconds, lr:8.59e-04
# epoch:651/2000 average TL:0.00013445 average VL:0.00005056 epoch time:1 seconds, lr:8.53e-04
# epoch:661/2000 average TL:0.00008680 average VL:0.00004299 epoch time:1 seconds, lr:8.47e-04
# epoch:671/2000 average TL:0.00009566 average VL:0.00002877 epoch time:1 seconds, lr:8.40e-04
# epoch:681/2000 average TL:0.00007991 average VL:0.00002675 epoch time:1 seconds, lr:8.34e-04
# epoch:691/2000 average TL:0.00008082 average VL:0.00002981 epoch time:1 seconds, lr:8.27e-04
# epoch:701/2000 average TL:0.00008916 average VL:0.00002126 epoch time:1 seconds, lr:8.21e-04
# epoch:711/2000 average TL:0.00008434 average VL:0.00002337 epoch time:1 seconds, lr:8.14e-04
# epoch:721/2000 average TL:0.00010232 average VL:0.00003053 epoch time:1 seconds, lr:8.07e-04
# epoch:731/2000 average TL:0.00009972 average VL:0.00002713 epoch time:1 seconds, lr:8.00e-04
# epoch:741/2000 average TL:0.00008970 average VL:0.00002667 epoch time:1 seconds, lr:7.93e-04
# epoch:751/2000 average TL:0.00008898 average VL:0.00003785 epoch time:1 seconds, lr:7.86e-04
# epoch:761/2000 average TL:0.00027388 average VL:0.00027704 epoch time:1 seconds, lr:7.79e-04
# epoch:771/2000 average TL:0.00026454 average VL:0.00009291 epoch time:1 seconds, lr:7.71e-04
# epoch:781/2000 average TL:0.00007973 average VL:0.00002717 epoch time:1 seconds, lr:7.64e-04
# epoch:791/2000 average TL:0.00009153 average VL:0.00002642 epoch time:1 seconds, lr:7.57e-04
# epoch:801/2000 average TL:0.00007829 average VL:0.00003655 epoch time:1 seconds, lr:7.49e-04
# epoch:811/2000 average TL:0.00007407 average VL:0.00001749 epoch time:1 seconds, lr:7.42e-04
# epoch:821/2000 average TL:0.00008149 average VL:0.00004965 epoch time:1 seconds, lr:7.34e-04
# epoch:831/2000 average TL:0.00006360 average VL:0.00002364 epoch time:1 seconds, lr:7.26e-04
# epoch:841/2000 average TL:0.00005937 average VL:0.00001468 epoch time:1 seconds, lr:7.18e-04
# epoch:851/2000 average TL:0.00007892 average VL:0.00001864 epoch time:1 seconds, lr:7.10e-04
# epoch:861/2000 average TL:0.00006013 average VL:0.00001381 epoch time:1 seconds, lr:7.02e-04
# epoch:871/2000 average TL:0.00006497 average VL:0.00002201 epoch time:1 seconds, lr:6.94e-04
# epoch:881/2000 average TL:0.00005974 average VL:0.00002182 epoch time:1 seconds, lr:6.86e-04
# epoch:891/2000 average TL:0.00006979 average VL:0.00003361 epoch time:1 seconds, lr:6.78e-04
# epoch:901/2000 average TL:0.00006070 average VL:0.00002067 epoch time:1 seconds, lr:6.70e-04
# epoch:911/2000 average TL:0.00005809 average VL:0.00001979 epoch time:1 seconds, lr:6.62e-04
# epoch:921/2000 average TL:0.00009374 average VL:0.00003515 epoch time:1 seconds, lr:6.54e-04
# epoch:931/2000 average TL:0.00005586 average VL:0.00001912 epoch time:1 seconds, lr:6.45e-04
# epoch:941/2000 average TL:0.00007086 average VL:0.00002510 epoch time:1 seconds, lr:6.37e-04
# epoch:951/2000 average TL:0.00011683 average VL:0.00003983 epoch time:1 seconds, lr:6.28e-04
# epoch:961/2000 average TL:0.00017784 average VL:0.00005414 epoch time:1 seconds, lr:6.20e-04
# epoch:971/2000 average TL:0.00006220 average VL:0.00002197 epoch time:1 seconds, lr:6.12e-04
# epoch:981/2000 average TL:0.00006025 average VL:0.00002693 epoch time:1 seconds, lr:6.03e-04
# epoch:991/2000 average TL:0.00005895 average VL:0.00002019 epoch time:1 seconds, lr:5.94e-04
# epoch:1001/2000 average TL:0.00005557 average VL:0.00001590 epoch time:1 seconds, lr:5.86e-04
# epoch:1011/2000 average TL:0.00006238 average VL:0.00002078 epoch time:1 seconds, lr:5.77e-04
# epoch:1021/2000 average TL:0.00006398 average VL:0.00001877 epoch time:1 seconds, lr:5.69e-04
# epoch:1031/2000 average TL:0.00005665 average VL:0.00001078 epoch time:1 seconds, lr:5.60e-04
# epoch:1041/2000 average TL:0.00008343 average VL:0.00005232 epoch time:1 seconds, lr:5.51e-04
# epoch:1051/2000 average TL:0.00032225 average VL:0.00005556 epoch time:1 seconds, lr:5.43e-04
# epoch:1061/2000 average TL:0.00007993 average VL:0.00002460 epoch time:1 seconds, lr:5.34e-04
# epoch:1071/2000 average TL:0.00008323 average VL:0.00002617 epoch time:1 seconds, lr:5.25e-04
# epoch:1081/2000 average TL:0.00004981 average VL:0.00001514 epoch time:1 seconds, lr:5.16e-04
# epoch:1091/2000 average TL:0.00004975 average VL:0.00000991 epoch time:1 seconds, lr:5.08e-04
# epoch:1101/2000 average TL:0.00006346 average VL:0.00002249 epoch time:1 seconds, lr:4.99e-04
# epoch:1111/2000 average TL:0.00007969 average VL:0.00002283 epoch time:1 seconds, lr:4.90e-04
# epoch:1121/2000 average TL:0.00005522 average VL:0.00001684 epoch time:1 seconds, lr:4.82e-04
# epoch:1131/2000 average TL:0.00008617 average VL:0.00003426 epoch time:1 seconds, lr:4.73e-04
# epoch:1141/2000 average TL:0.00005501 average VL:0.00002139 epoch time:1 seconds, lr:4.64e-04
# epoch:1151/2000 average TL:0.00006005 average VL:0.00002005 epoch time:1 seconds, lr:4.55e-04
# epoch:1161/2000 average TL:0.00006035 average VL:0.00001527 epoch time:1 seconds, lr:4.47e-04
# epoch:1171/2000 average TL:0.00005576 average VL:0.00001328 epoch time:1 seconds, lr:4.38e-04
# epoch:1181/2000 average TL:0.00006140 average VL:0.00002207 epoch time:1 seconds, lr:4.29e-04
# epoch:1191/2000 average TL:0.00012664 average VL:0.00003224 epoch time:1 seconds, lr:4.21e-04
# epoch:1201/2000 average TL:0.00031031 average VL:0.00015674 epoch time:1 seconds, lr:4.12e-04
# epoch:1211/2000 average TL:0.00006897 average VL:0.00003324 epoch time:1 seconds, lr:4.04e-04
# epoch:1221/2000 average TL:0.00006365 average VL:0.00002011 epoch time:1 seconds, lr:3.95e-04
# epoch:1231/2000 average TL:0.00005078 average VL:0.00001605 epoch time:1 seconds, lr:3.87e-04
# epoch:1241/2000 average TL:0.00005891 average VL:0.00002430 epoch time:1 seconds, lr:3.78e-04
# epoch:1251/2000 average TL:0.00006047 average VL:0.00001869 epoch time:1 seconds, lr:3.70e-04
# epoch:1261/2000 average TL:0.00005039 average VL:0.00001140 epoch time:1 seconds, lr:3.61e-04
# epoch:1271/2000 average TL:0.00005541 average VL:0.00001574 epoch time:1 seconds, lr:3.53e-04
# epoch:1281/2000 average TL:0.00004505 average VL:0.00001030 epoch time:1 seconds, lr:3.45e-04
# epoch:1291/2000 average TL:0.00004656 average VL:0.00001386 epoch time:1 seconds, lr:3.36e-04
# epoch:1301/2000 average TL:0.00013167 average VL:0.00002803 epoch time:1 seconds, lr:3.28e-04
# epoch:1311/2000 average TL:0.00006287 average VL:0.00002548 epoch time:1 seconds, lr:3.20e-04
# epoch:1321/2000 average TL:0.00005381 average VL:0.00001778 epoch time:1 seconds, lr:3.12e-04
# epoch:1331/2000 average TL:0.00005543 average VL:0.00002310 epoch time:1 seconds, lr:3.04e-04
# epoch:1341/2000 average TL:0.00004459 average VL:0.00000970 epoch time:1 seconds, lr:2.96e-04
# epoch:1351/2000 average TL:0.00005007 average VL:0.00001705 epoch time:1 seconds, lr:2.88e-04
# epoch:1361/2000 average TL:0.00005189 average VL:0.00001582 epoch time:1 seconds, lr:2.80e-04
# epoch:1371/2000 average TL:0.00003877 average VL:0.00000849 epoch time:1 seconds, lr:2.72e-04
# epoch:1381/2000 average TL:0.00004136 average VL:0.00000933 epoch time:1 seconds, lr:2.64e-04
# epoch:1391/2000 average TL:0.00004397 average VL:0.00001316 epoch time:1 seconds, lr:2.57e-04
# epoch:1401/2000 average TL:0.00004286 average VL:0.00001019 epoch time:1 seconds, lr:2.49e-04
# epoch:1411/2000 average TL:0.00003746 average VL:0.00000687 epoch time:1 seconds, lr:2.42e-04
# epoch:1421/2000 average TL:0.00004765 average VL:0.00000975 epoch time:1 seconds, lr:2.34e-04
# epoch:1431/2000 average TL:0.00003809 average VL:0.00000934 epoch time:1 seconds, lr:2.27e-04
# epoch:1441/2000 average TL:0.00004219 average VL:0.00001025 epoch time:1 seconds, lr:2.20e-04
# epoch:1451/2000 average TL:0.00003834 average VL:0.00000661 epoch time:1 seconds, lr:2.12e-04
# epoch:1461/2000 average TL:0.00003848 average VL:0.00000525 epoch time:1 seconds, lr:2.05e-04
# epoch:1471/2000 average TL:0.00004354 average VL:0.00000600 epoch time:1 seconds, lr:1.98e-04
# epoch:1481/2000 average TL:0.00003606 average VL:0.00000548 epoch time:1 seconds, lr:1.91e-04
# epoch:1491/2000 average TL:0.00004278 average VL:0.00000775 epoch time:1 seconds, lr:1.85e-04
# epoch:1501/2000 average TL:0.00003784 average VL:0.00000707 epoch time:1 seconds, lr:1.78e-04
# epoch:1511/2000 average TL:0.00003923 average VL:0.00000678 epoch time:1 seconds, lr:1.71e-04
# epoch:1521/2000 average TL:0.00004186 average VL:0.00000891 epoch time:1 seconds, lr:1.65e-04
# epoch:1531/2000 average TL:0.00003872 average VL:0.00000541 epoch time:1 seconds, lr:1.58e-04
# epoch:1541/2000 average TL:0.00003410 average VL:0.00000517 epoch time:1 seconds, lr:1.52e-04
# epoch:1551/2000 average TL:0.00004288 average VL:0.00000480 epoch time:1 seconds, lr:1.46e-04
# epoch:1561/2000 average TL:0.00003538 average VL:0.00000450 epoch time:1 seconds, lr:1.40e-04
# epoch:1571/2000 average TL:0.00003401 average VL:0.00000416 epoch time:1 seconds, lr:1.34e-04
# epoch:1581/2000 average TL:0.00003675 average VL:0.00000456 epoch time:1 seconds, lr:1.28e-04
# epoch:1591/2000 average TL:0.00003514 average VL:0.00000389 epoch time:1 seconds, lr:1.22e-04
# epoch:1601/2000 average TL:0.00003156 average VL:0.00000313 epoch time:1 seconds, lr:1.16e-04
# epoch:1611/2000 average TL:0.00003655 average VL:0.00000508 epoch time:1 seconds, lr:1.11e-04
# epoch:1621/2000 average TL:0.00003506 average VL:0.00000519 epoch time:1 seconds, lr:1.05e-04
# epoch:1631/2000 average TL:0.00003285 average VL:0.00000395 epoch time:1 seconds, lr:1.00e-04
# epoch:1641/2000 average TL:0.00003132 average VL:0.00000317 epoch time:1 seconds, lr:9.49e-05
# epoch:1651/2000 average TL:0.00003052 average VL:0.00000370 epoch time:1 seconds, lr:8.99e-05
# epoch:1661/2000 average TL:0.00003105 average VL:0.00000371 epoch time:1 seconds, lr:8.50e-05
# epoch:1671/2000 average TL:0.00003633 average VL:0.00000734 epoch time:1 seconds, lr:8.02e-05
# epoch:1681/2000 average TL:0.00005551 average VL:0.00001803 epoch time:1 seconds, lr:7.55e-05
# epoch:1691/2000 average TL:0.00003663 average VL:0.00000863 epoch time:1 seconds, lr:7.09e-05
# epoch:1701/2000 average TL:0.00003277 average VL:0.00000547 epoch time:1 seconds, lr:6.65e-05
# epoch:1711/2000 average TL:0.00003113 average VL:0.00000639 epoch time:1 seconds, lr:6.22e-05
# epoch:1721/2000 average TL:0.00003263 average VL:0.00000516 epoch time:1 seconds, lr:5.81e-05
# epoch:1731/2000 average TL:0.00003181 average VL:0.00000508 epoch time:1 seconds, lr:5.41e-05
# epoch:1741/2000 average TL:0.00003391 average VL:0.00000460 epoch time:1 seconds, lr:5.02e-05
# epoch:1751/2000 average TL:0.00003152 average VL:0.00000493 epoch time:1 seconds, lr:4.65e-05
# epoch:1761/2000 average TL:0.00003180 average VL:0.00000446 epoch time:1 seconds, lr:4.29e-05
# epoch:1771/2000 average TL:0.00002935 average VL:0.00000476 epoch time:1 seconds, lr:3.94e-05
# epoch:1781/2000 average TL:0.00002994 average VL:0.00000442 epoch time:1 seconds, lr:3.61e-05
# epoch:1791/2000 average TL:0.00003010 average VL:0.00000398 epoch time:1 seconds, lr:3.29e-05
# epoch:1801/2000 average TL:0.00002965 average VL:0.00000364 epoch time:1 seconds, lr:2.99e-05
# epoch:1811/2000 average TL:0.00002975 average VL:0.00000412 epoch time:1 seconds, lr:2.70e-05
# epoch:1821/2000 average TL:0.00003037 average VL:0.00000356 epoch time:1 seconds, lr:2.42e-05
# epoch:1831/2000 average TL:0.00002899 average VL:0.00000318 epoch time:1 seconds, lr:2.16e-05
# epoch:1841/2000 average TL:0.00003197 average VL:0.00000309 epoch time:1 seconds, lr:1.91e-05
# epoch:1851/2000 average TL:0.00002874 average VL:0.00000313 epoch time:1 seconds, lr:1.68e-05
# epoch:1861/2000 average TL:0.00002898 average VL:0.00000345 epoch time:1 seconds, lr:1.47e-05
# epoch:1871/2000 average TL:0.00002958 average VL:0.00000308 epoch time:1 seconds, lr:1.26e-05
# epoch:1881/2000 average TL:0.00002917 average VL:0.00000299 epoch time:1 seconds, lr:1.08e-05
# epoch:1891/2000 average TL:0.00003103 average VL:0.00000291 epoch time:1 seconds, lr:9.04e-06
# epoch:1901/2000 average TL:0.00003007 average VL:0.00000309 epoch time:1 seconds, lr:7.46e-06
# epoch:1911/2000 average TL:0.00002958 average VL:0.00000281 epoch time:1 seconds, lr:6.04e-06
# epoch:1921/2000 average TL:0.00003030 average VL:0.00000271 epoch time:1 seconds, lr:4.77e-06
# epoch:1931/2000 average TL:0.00002834 average VL:0.00000269 epoch time:1 seconds, lr:3.65e-06
# epoch:1941/2000 average TL:0.00002796 average VL:0.00000280 epoch time:1 seconds, lr:2.68e-06
# epoch:1951/2000 average TL:0.00002866 average VL:0.00000269 epoch time:1 seconds, lr:1.86e-06
# epoch:1961/2000 average TL:0.00002859 average VL:0.00000288 epoch time:1 seconds, lr:1.19e-06
# epoch:1971/2000 average TL:0.00003140 average VL:0.00000280 epoch time:1 seconds, lr:6.74e-07
# epoch:1981/2000 average TL:0.00003018 average VL:0.00000282 epoch time:1 seconds, lr:3.11e-07
# epoch:1991/2000 average TL:0.00002905 average VL:0.00000272 epoch time:1 seconds, lr:9.97e-08
# Training completed in 2791.50 seconds
# Model FLOPs: 134298826.0
# Model Params Num: 63839677.0
#
#
# --- Single Run Results ---
# Grid Size: 10m
# Mean 2D Error: 0.86 meters
# 90th Percentile Error: 1.36 meters
# Grid Accuracy (Reciprocal): 0.9176
# Grid Accuracy (Gaussian): 0.9176
# Grid Accuracy (Softmax): 0.9176
# Training Time: 2791.50 seconds
#
# --- Starting Multiple Run Analysis (50 runs) ---
# Run 1/50...
# Run 11/50...
# Run 21/50...
# Run 31/50...
# Run 41/50...
#
# --- Multiple Run Results with 95% Confidence Intervals ---
# Mean 2D Error: 0.81 ± 0.01 meters
# 90th Percentile Error: 1.24 ± 0.01 meters
# Grid Accuracy (Reciprocal): 0.9222 ± 0.0009
# Grid Accuracy (Gaussian): 0.9222 ± 0.0009
# Grid Accuracy (Softmax): 0.9222 ± 0.0009
#
# All results saved to finalmodels/CNN/Grid_10m/batch_size_3000/initial_lr_0.001/epochs2000_p500_hs4196/
# Training time: 2791.50 seconds
# Total evaluation time for 50 runs: 252.57 seconds
